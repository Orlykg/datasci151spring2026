# %% [markdown]
# # <span style="color:red"> DATASCI 151 - Practice Quiz </span>

# %% [markdown]
# <font size = "4" >
# This quiz is open book
#
# <br>
#
# - You <span style="color:red"> CAN </span> use all material from the course repo
#
# - You should <span style="color:red"> NOT </span> use other resources outside the course repo.
#
# - You should <span style="color:red"> NOT </span> collaborate with other students
#
# - Use of LLMs or any AI tools is <span style="color:red"> NOT ALLOWED </span>
#
# - To get full credit, the code should work as intended. But try to attempt every problem - you can still receive partial credit.
#
# <br>
#
# Print the following string:
#
# "I will abide by Emory's code of conduct"

# %%
print("I will abide by Emory's code of conduct")

# %% [markdown]
# <font size = "4">
#
# Import the libraries `numpy`, `matplotlib.pyplot`, and `pandas`. You probably want to give them aliases (nicknames) but it's not required.

# %%
# import necessary libraries here
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 # import necessary libraries here
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import pandas as pd
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/__init__.py:1001
#     995     _log.debug('loaded rc file %s', fname)
#     997     return config
#    1000 rcParamsDefault = _rc_params_in_file(
# -> 1001     cbook._get_data_path("matplotlibrc"),
#    1002     # Strip leading comment.
#    1003     transform=lambda line: line[1:] if line.startswith("#") else line,
#    1004     fail_on_error=True)
#    1005 rcParamsDefault._update_raw(rcsetup._hardcoded_defaults)
#    1006 rcParamsDefault._ensure_has_backend()
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/cbook.py:603, in _get_data_path(*args)
#     597 def _get_data_path(*args):
# ...

# %% [markdown]
# <font size = "4">
#
# **Q1** Looping over Filenames
#
# <font size = "3">
#
# **Finsh this problem without changing the file structure of the "quiz_3" folder**
#
# 1. Use the `os.listdir` function to create a list containing all the file names inside the "country_emissions" subfolder (which is inside the "quiz_data" folder).
#
# 2. Create an empty list called `df_list`.
#
# 3. Write a for-loop that loops over the elements of the list you created with `os.listdir`. For each file:
#
# - Read in the file using `pd.read_csv()`, creating a Pandas DataFrame object.
#
# - Append the DataFrame object to `df_list`
#
# 4. After the loop:
# - Print the number of DataFrames in `df_list` using a suitable Python command
#
# - Print the shape of the first DataFrame. **Note:** Suppose a single DataFrame called `df` has been defined. You can determine its shape by typing `df.shape`

# %%
# complete the code
import os
import pandas as pd

folder_path = "quiz_data/country_emissions"
file_list = os.listdir(folder_path)

df_list = []

for file in file_list: 
    file_path = os.path.join(folder_path, file) 
    df = pd.read_csv(file_path)
    df_list.append(df)

print(len(df_list))
print(df_list[0].shape)
# Out:
# 11
# (27, 4)

# %% [markdown]
# <font size = "4">
#
# **Q2** Quadratic Formula
#
# <font size = "3">
#
# Consider solving the quadratic equation $ax^2 + bx + c = 0$. In addition to the standard quadratic formula, the following is an equivalent way of expressing the two solutions:
#
# $$ x = \frac{2c}{-b \mp \sqrt{b^2 - 4ac}}$$
#
# 1. Write a function called `alt_quad_formula` that takes in 3 input arguments corresponding to the coefficients $a$, $b$, and $c$ and returns the two solutions to the corresponding quadratic equation computed using the expression above.
#
# 2. Test your function on the quadratic equation $3(x + 1)(x - 2) = 0$, verifying you get the outputs $-1$ and $2$.

# %%
import numpy as np
### Your solution below

def alt_quad_formula(a, b, c): 
    discriminant = np.sqrt(b**2 - 4*a*c)
    x1 = (2*c) / (-b + discriminant)
    x2 = (2*c) / (-b - discriminant)
    return float(x1), float(x2)

roots = alt_quad_formula(3, -3, 6)
print(roots)
# Out:
# (nan, nan)
# /var/folders/22/c9dly99x2zz99bqrh67frh8h0000gn/T/ipykernel_22193/266882579.py:5: RuntimeWarning: invalid value encountered in sqrt
#   discriminant = np.sqrt(b**2 - 4*a*c)

# %% [markdown]
# <font size = "4">
#
# **Q3** Function with no argument
#
# <font size = "3">
#
# Write a function that doesn't return any values (just like the `print` function).
#
# The function takes in 3 arguments, with the following keywords:
#
# - `vec_x`: A sequence of values (like a list, tuple, NumPy array, or column from a Pandas DataFrame).
#
# - `xlabel`: A string
#
# - `title`: A string
#
# The function creates a histogram of the values in `vec_x`, labels the x-axis using the `xlabel` argument, always labels the y-axis with the string `"Frequency"`, and adds a title using the `title` argument. It then displays the histogram to the screen.
#
# The function should have **no return values**. You can do this by having the last line of the function read `return None`. Or simply don't include a return statement at all.

# %%
# create your function here

def create_histogram(vec_x, xlabel, title):
# Out:
#   Cell In[9], line 4
#
#     ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# <font size = "3">
#
#
# **Check:** If your code works, the next cell should display **two** appropriately labeled histograms.

# %%
import pandas as pd

# %% [markdown]
# <font size = "4">
#
# **Q4** Subsetting data
#
# <font size = "3">
#
# - Read in the dataset named "fifa23_players_basic.csv", assigning it to a DataFrame object. Each row of the dataset corresponds to a professional soccer (football) player.
#
# - View the dataset and look for the name of the column corresponding to height in cm (centimeters). (No code/output is expected for this part).
#
# - Using the ``.query`` method, extract the subset of players whose value of the height variable is **greater than** 175<br> and assign it to a new DataFrame called `df_tall`
#
# - Using ``.shape``, define an integer variable ``num_tall`` which is the number of players who are above this height threshold.
#
# **Hint:** Print the variable ``num_tall`` when you are done. Is it an integer?

# %%
import pandas as pd

# your code here

# %% [markdown]
# <font size = "4">
#
# **Q5** Create a function and apply it to a column <br>
#
# <font size = "3">
#
# For this problem, use the same dataset/DataFrame as in Q4.
#
# Step 1:
# - Define a function with a single input argument "Overall" which classifies each player as follows:
#     - If "Overall > 85", the function returns the string "Top Performer"
#     - If "Overall <= 85", the function returns the string "Non Top-Performer"
#
# Step 2:
# - Extract the column "Overall" from the FIFA players DataFrame, and assign it to a variable (which should be a Pandas Series) <br>
#
# - Using the Pandas ``.apply`` method, create a new Pandas Series called "player_classification" which contains the appropriate string for each player.

# %%
import pandas as pd
### Your solution below

# %% [markdown]
# <font size = "4">
#
# **Q6** Split a dataset into subsets
#
#
# <font size = "3">
#
# - We will continue using the DataFrame you read in from "fifa23_players_basic.csv"
#
# - Use ``len`` or ``.shape`` to define an integer variable called ``n``, which is the total number of rows in this DataFrame. <br>
#
# - Use ``numpy.random.uniform`` to create a random sample of size ``n`` from the uniform distribution between 0 and 1. Then store these random numbers as a new column named "random_var" to the original DataFrame.<br>
# - Use ``.query`` to extract all players with ```random_var < 0.4```, and assign it to a new DataFrame called ``groupA``
# - Use ``.query`` to extract all players with ```random_var >= 0.4```, and assign it to a new DataFrame called ``groupB``.
#
# **Note**: In this way, we are assigning roughly 40% of the players to Group A, and roughly 60% to Group B

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Using the FIFA dataset:
#
# Use .query() to create a new DataFrame called df_high_potential containing players with Potential > 85
#
# Define a variable avg_value equal to the average Value (in Euro) of players in this subset
#
# Print avg_value

# %% [markdown]
# Write a function called wage_level that takes in a player's Wage and returns:
#
# "High" if Wage > 100000
#
# "Medium" if 50000 ≤ Wage ≤ 100000
#
# "Low" if Wage < 50000
#
# Step 2:
#
# Apply this function to the "Wage" column using .apply()
#
# Store the result in a new column called "wage_category"

# %% [markdown]
# Use .shape or len() to define n, the number of rows
#
# Create a column "rand" using np.random.uniform(0,1,n)
#
# Create:
#
# df_sample1 with "rand < 0.25"
#
# df_sample2 with "rand >= 0.25"
#
# Print the number of rows in each group

# %% [markdown]
# Use .query() to create a DataFrame df_young_stars where:
#
# Potential > 85 AND Age < 25
#
# Define a variable num_young_stars equal to the number of players in this group
#
# Print num_young_stars

# %% [markdown]
# Question 1 (easy)
#
# Select the "mpg" column using .loc.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Question 2 (easy)
#
# Select the first 5 rows of the entire DataFrame using .iloc.

# %% [markdown]
# Question 3 (medium)
#
# Select rows where cylinders == 6 and return only "mpg" using .loc

# %% [markdown]
# Question 4 (medium)
#
# Using .iloc, select:
#
# rows 0–9
#
# columns 0–2

# %% [markdown]
# Question 5 (medium+)
#
# Select the "mpg" and "weight" columns for rows where mpg > 30 using .loc.

# %% [markdown]
# Question 6 (tricky)
#
# Using .iloc, select the last 3 rows of the DataFrame.

# %% [markdown]
# Question 7 (tricky)
#
# Using .loc, select rows with index labels from 5 to 10 (inclusive) and all columns.

# %% [markdown]
# Question 8 (very testable)
#
# What does this return? (be precise)
#
# df.iloc[0:3, 0:2]

# %% [markdown]
# Question 9 (very tricky)
#
# Fix this line:
#
# df.iloc[df["mpg"] > 25, "mpg"]

# %% [markdown]
# Question 10 (hard)
#
# Using .loc, select:
#
# rows where cylinders is 4 or 6
#
# columns "mpg" and "horsepower"
